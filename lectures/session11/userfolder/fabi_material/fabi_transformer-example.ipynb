# %% [markdown]
# # Use a pretrained Transformer to predict SMILES
#
# Load model: GPT2LMHeadModel - trained for predicting smiles

# %%
from transformers import GPT2LMHeadModel, PreTrainedTokenizerFast

# Load tokenizer & pretrained model
tokenizer = PreTrainedTokenizerFast.from_pretrained(
    "jonghyunlee/MolGPT_pretrained-by-ZINC15"
)

tokenizer.pad_token = "<pad>"
tokenizer.bos_token = "<bos>"
tokenizer.eos_token = "<eos>"

model = GPT2LMHeadModel.from_pretrained("jonghyunlee/MolGPT_pretrained-by-ZINC15")
model.eval()

def generate_smiles(n=5, temperature=1.0):
    outputs = model.generate(
        max_length=128,
        num_return_sequences=n,
        do_sample=True,
        temperature=temperature,
        bos_token_id=tokenizer.bos_token_id,
        eos_token_id=tokenizer.eos_token_id,
        pad_token_id=tokenizer.pad_token_id
    )
    return [tokenizer.decode(o, skip_special_tokens=True) for o in outputs]

# Test generation
print("Generated SMILES:")
for smi in generate_smiles(5):
    print(smi)
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# tokenizer_config.json:   0%|          | 0.00/891 [00:00<?, ?B/s]
# c:\Users\fabie\DSA104_git\DSA104Fork\DSA104\.venv\Lib\site-packages\huggingface_hub\file_download.py:129: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\fabie\.cache\huggingface\hub\models--jonghyunlee--MolGPT_pretrained-by-ZINC15. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/75.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/822 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/27.6M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/100 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/119 [00:00<?, ?B/s]
# Generated SMILES:
#  O=C(CCn1cnc2ccccc21)N[C@@H]1CN([C@H]2CCNC2=O)C[C@H]1O
#  O=C(c1cn(-c2ccccc2)nn1)N1CCO[C@]2(CCN(C(=O)[C@@H]3C[C@H](O)CN3)C2)C1
#  C[C@@H](CCNC(=O)CNC(N)=O)NC(=O)C[C@H]1CCNC1=O
#  Cc1cn(C)nc1C(=O)N[C@@H]1CC(=O)N(C2CN(Cc3ncccn3)C2)C1
#  O=C(Cn1nnc2c1CCCC2)N1CC(NC(=O)[C@@]23COC[C@@H]2C3)C1
